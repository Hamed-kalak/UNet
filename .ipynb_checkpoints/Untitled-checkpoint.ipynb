# %%
import os.path
import json
import scipy.misc
import numpy as np
import matplotlib.pyplot as plt

global counter
counter = 0


# In this exercise task you will implement an image generator. Generator objects in python are defined as having a next function.
# This next function returns the next generated object. In our case it returns the input of a neural network each time it gets called.
# This input consists of a batch of images and its corresponding labels.
class ImageGenerator:
    def __init__(self, file_path, label_path, batch_size, image_size, rotation=False, mirroring=False, shuffle=False):
        # Define all members of your generator class object as global members here.
        # These need to include:
        # the batch size
        # the image size
        # flags for different augmentations and whether the data should be shuffled for each epoch
        # Also depending on the size of your data-set you can consider loading all images into memory here already.
        # The labels are stored in json format and can be directly loaded as dictionary.
        # Note that the file names correspond to the dicts of the label dictionary.

        self.class_dict = {0: 'airplane', 1: 'automobile', 2: 'bird', 3: 'cat', 4: 'deer', 5: 'dog', 6: 'frog',
                           7: 'horse', 8: 'ship', 9: 'truck'}
        # TODO: implement constructor
        self.file_path = file_path
        self.label_path = label_path
        self.batch_size = batch_size
        self.image_size = image_size
        self.rotation = rotation
        self.mirroring = mirroring
        self.shuffle = shuffle
        self.epoch = 0

        if self.shuffle == True:
            self.order = self.shuffler
        else:
            self.order = np.arange(100)

        global counter

    def shuffler(self):
        ans = np.random.choice(np.arange(0, 100), size=100, replace=False)
        return np.array(ans)

    def next(self):
        # This function creates a batch of images and corresponding labels and returns them.
        # In this context a "batch" of images just means a bunch, say 10 images that are forwarded at once.
        # Note that your amount of total data might not be divisible without remainder with the batch_size.
        # Think about how to handle such cases
        # TODO: implement next method
        images = []
        labels = []

        global counter
        with open(self.label_path, 'r') as f:
            data = json.load(f)

            for _ in range(self.batch_size):

                if counter == len(data):
                    counter = counter - 100
                    self.shuffler()
                    self.epoch = self.epoch + 1

                img_label = str(data[str(self.order[counter])])

                img = np.load(self.file_path + '/' + str(self.order[counter]) + '.npy')
                img.resize(self.image_size)

                img = self.augment(img)

                images.append(img)
                labels.append(img_label)
                counter = counter + 1


            return images, labels

    def augment(self, img):
        # this function takes a single image as an input and performs a random transformation
        # (mirroring and/or rotation) on it and outputs the transformed image
        # TODO: implement augmentation function

        if self.mirroring == True:
            if np.random.random() > 0.5:
                img = np.fliplr(img)

        if self.mirroring == True:
            k = np.random.choice([0, 1, 2, 3])
            img = np.rot90(img, k=k)

        return img

    def current_epoch(self):
        # return the current epoch number
        return self.epoch

    def class_name(self, x):
        # This function returns the class name for a specific input
        # TODO: implement class name function
        return self.class_dict[x]

    def show(self):
        # In order to verify that the generator creates batches as required, this functions calls next to get a
        # batch of images and labels and visualizes it.
        # TODO: implement show method
        img, label = self.next()

        fig, axes = plt.subplots(nrows=1, ncols=len(img), figsize=(10, 4))

        for i, ax in enumerate(axes):
            ax.imshow(img[i])

            ax.set_title(self.class_name(int(label[i])))

        plt.tight_layout()
        plt.show()

# %%
file_path = '/Users/macbookpro/Desktop/Educational/FAU/4th Semester/DeepL/exercise0_material/src_to_implement/data/exercise_data'
label_path = '/Users/macbookpro/Desktop/Educational/FAU/4th Semester/DeepL/exercise0_material/src_to_implement/data/Labels.json'
test1 = ImageGenerator(file_path,label_path,50,32)
test1.self.order()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-335-e4f44e15358b> in <module>
#       2 label_path = '/Users/macbookpro/Desktop/Educational/FAU/4th Semester/DeepL/exercise0_material/src_to_implement/data/Labels.json'
#       3 test1 = ImageGenerator(file_path,label_path,50,32)
# ----> 4 test1.self.order()
#       5
#       6
#
# AttributeError: 'ImageGenerator' object has no attribute 'self'

# %%
import os.path
import json
import scipy.misc
import numpy as np
import matplotlib.pyplot as plt





# In this exercise task you will implement an image generator. Generator objects in python are defined as having a next function.
# This next function returns the next generated object. In our case it returns the input of a neural network each time it gets called.
# This input consists of a batch of images and its corresponding labels.
class ImageGenerator:
    def __init__(self, file_path, label_path, batch_size, image_size, rotation=False, mirroring=False, shuffle=False):
        # Define all members of your generator class object as global members here.
        # These need to include:
        # the batch size
        # the image size
        # flags for different augmentations and whether the data should be shuffled for each epoch
        # Also depending on the size of your data-set you can consider loading all images into memory here already.
        # The labels are stored in json format and can be directly loaded as dictionary.
        # Note that the file names correspond to the dicts of the label dictionary.

        self.class_dict = {0: 'airplane', 1: 'automobile', 2: 'bird', 3: 'cat', 4: 'deer', 5: 'dog', 6: 'frog',
                           7: 'horse', 8: 'ship', 9: 'truck'}
        # TODO: implement constructor
        self.file_path = file_path
        self.label_path = label_path
        self.batch_size = batch_size
        self.image_size = image_size
        self.rotation = rotation
        self.mirroring = mirroring
        self.shuffle = shuffle
        self.epoch = 0

        if self.shuffle == True:
            self.order = self.shuffler
        else:
            self.order = np.arange(self.batch_size)

        with open(self.label_path, 'r') as f:
            self.labels = json.load(f)

    def shuffler(self):
        ans = np.random.choice(np.arange(0, self.batch_size), size=self.batch_size , replace=False)
        return np.array(ans)

    def next(self):
        # This function creates a batch of images and corresponding labels and returns them.
        # In this context a "batch" of images just means a bunch, say 10 images that are forwarded at once.
        # Note that your amount of total data might not be divisible without remainder with the batch_size.
        # Think about how to handle such cases
        # TODO: implement next method
        images = []
        labels = []
        counter = 0


            for _ in range(self.batch_size):

                if counter == len(data):
                    self.shuffler()
                    self.epoch = self.epoch + 1

                img_label = self.labels[str(self.order[counter])]

                img = np.load(self.file_path + '/' + str(self.order[counter]) + '.npy')
#                 img.resize(self.image_size)

                img = self.augment(img)

                images.append(img)
                labels.append(img_label)
                counter = counter + 1


            return images, labels

    def augment(self, img):
        # this function takes a single image as an input and performs a random transformation
        # (mirroring and/or rotation) on it and outputs the transformed image
        # TODO: implement augmentation function

        if self.mirroring == True:
            if np.random.random() > 0.5:
                img = np.fliplr(img)

        if self.mirroring == True:
            k = np.random.choice([0, 1, 2, 3])
            img = np.rot90(img, k=k)

        return img

    def current_epoch(self):
        # return the current epoch number
        return self.epoch

    def class_name(self, x):
        # This function returns the class name for a specific input
        # TODO: implement class name function
        return self.class_dict[x]

    def show(self):
        # In order to verify that the generator creates batches as required, this functions calls next to get a
        # batch of images and labels and visualizes it.
        # TODO: implement show method
        img, label = self.next()

        fig, axes = plt.subplots(nrows=1, ncols=len(img), figsize=(10, 4))

        for i, ax in enumerate(axes):

            ax.imshow(img[i])

            ax.set_title(self.class_name(int(label[i])))

        plt.tight_layout()
        plt.show()
# Out:
#   File "<ipython-input-379-7b6b43ede9c2>", line 60
#     for _ in range(self.batch_size):
#     ^
# IndentationError: unexpected indent

# %%
file_path = '/Users/macbookpro/Desktop/Educational/FAU/4th Semester/DeepL/exercise0_material/src_to_implement/data/exercise_data'
label_path = '/Users/macbookpro/Desktop/Educational/FAU/4th Semester/DeepL/exercise0_material/src_to_implement/data/Labels.json'
test1 = ImageGenerator(file_path,label_path,5,500)
test1.show()
